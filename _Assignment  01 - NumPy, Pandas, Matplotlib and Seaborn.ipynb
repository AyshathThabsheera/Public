# %%
# import python packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset to python environment

# %%
data=pd.read_excel(r'C:\Users\USER\OneDrive\Desktop\thabshi\DSA class\iris.xls')

# %% [markdown]
# # Displaying the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculating the mean of each column of the dataset

# %%
data[['SL','SW', 'PL', 'PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # visualizations using the dataset

# %%
#bar plot

# %%
plt.bar(data['Classification'],data['PW'])
plt.xticks(rotation=90)
plt.title('Classification based on Petal width')
plt.show()

# %%
#box plot

# %%
plt.boxplot(data['SW'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19eff5f51b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19eff5f5690>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19eff5f4e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x19eff5f5bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19eff5f5e70>],
#  'means': []}

# %%
# histogram

# %%
plt.hist(data['PL'])
plt.title('Petal Length')
plt.show()
